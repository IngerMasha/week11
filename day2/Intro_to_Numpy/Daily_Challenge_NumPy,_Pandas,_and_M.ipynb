# %% [markdown]
# <a href="https://colab.research.google.com/github/IngerMasha/week11/blob/main/day2/Intro_to_Numpy/Daily_Challenge_NumPy%2C_Pandas%2C_and_M.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

cities = [f'City_{i+1}' for i in range(10)]
months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']

np.random.seed(42)
temperature_data = np.random.uniform(low=-5, high=35, size=(10, 12))

df = pd.DataFrame(data=temperature_data, index=cities, columns=months)

print(df.head())
# Out:
#               Jan        Feb        Mar        Apr        May        Jun  \
# City_1   9.981605  33.028572  24.279758  18.946339   1.240746   1.239781
# City_2  28.297706   3.493564   2.272999   2.336180   7.169690  15.990257
# City_3  13.242799  26.407038   2.986951  15.569378  18.696583  -3.141983
# City_4   7.184551  -1.093115  22.369321  12.606100  -0.118471  14.807076
# City_5  16.868411   2.394178  33.783385  26.005313  32.579958  30.793094
#
#               Jul        Aug        Sep        Oct        Nov        Dec
# City_1  -2.676656  29.647046  19.044600  23.322903  -4.176620  33.796394
# City_2  12.277801   6.649166  19.474116   0.579754   6.685786   9.654474
# City_3  19.301794   1.820965  -2.397936  32.955421  33.625281  27.335894
# City_4  -3.624459  31.372816   5.351199  21.500891   7.468443  15.802721
# City_5  18.915999  31.874969  -1.460300   2.839314  -3.190908   8.013213

# %%
df['Annual_Avg_Temperature'] = df.mean(axis=1)

highest_avg_city = df['Annual_Avg_Temperature'].idxmax()
lowest_avg_city = df['Annual_Avg_Temperature'].idxmin()

print(f'City with the highest average temperature: {highest_avg_city}')
print(f'City with the lowest average temperature: {lowest_avg_city}')
print(df[['Annual_Avg_Temperature']])
# Out:
# City with the highest average temperature: City_8
# City with the lowest average temperature: City_2
#          Annual_Avg_Temperature
# City_1                15.639539
# City_2                 9.573458
# City_3                15.533515
# City_4                11.135589
# City_5                16.618052
# City_6                13.815557
# City_7                13.191186
# City_8                17.608070
# City_9                11.323811
# City_10               16.405255

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(14, 8))
for city in cities:
    plt.plot(df.columns[:-1], df.loc[city, df.columns[:-1]], marker='o', label=city)

plt.title('Monthly Temperature Trends for Each City')
plt.xlabel('Month')
plt.ylabel('Temperature (°C)')
plt.legend(title='Cities', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Annual_Avg_Temperature'], bins=10, kde=True, color='skyblue')
plt.title('Distribution of Annual Average Temperatures')
plt.xlabel('Annual Average Temperature (°C)')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()
