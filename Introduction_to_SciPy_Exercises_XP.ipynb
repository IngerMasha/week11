# %% [markdown]
# <a href="https://colab.research.google.com/github/IngerMasha/week11/blob/main/Introduction_to_SciPy_Exercises_XP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import scipy
print("SciPy version:", scipy.__version__)
# Out:
# SciPy version: 1.13.1

# %%
import numpy as np

data = [12, 15, 13, 12, 18, 20, 22, 21]
mean = np.mean(data)
median = np.median(data)
variance = np.var(data, ddof=1)  # Sample variance
std_dev = np.std(data, ddof=1)  # Sample standard deviation
print("Mean:", mean)
print("Median:", median)
print("Variance:", variance)
print("Standard Deviation:", std_dev)
# Out:
# Mean: 16.625
# Median: 16.5
# Variance: 17.125
# Standard Deviation: 4.138236339311712

# %%
import matplotlib.pyplot as plt
from scipy.stats import norm

mean = 50
std_dev = 10
size = 1000
data = np.random.normal(mean, std_dev, size)

plt.figure(figsize=(10, 6))
plt.hist(data, bins=30, density=True, alpha=0.6, color='g')

xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = norm.pdf(x, mean, std_dev)
plt.plot(x, p, 'k', linewidth=2)

plt.title('Normal Distribution')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
data1 = np.random.normal(0, 1, 100)
data2 = np.random.normal(0, 1, 100)

t_statistic, p_value = stats.ttest_ind(data1, data2)
print("T-statistic:", t_statistic)
print("P-value:", p_value)
# Out:
# T-statistic: 1.399022832553352
# P-value: 0.1633706709875098

# %%
import pandas as pd
from scipy import stats

df = pd.read_csv('/content/iris.csv')
sepal_length = df['sepal_length']
mean = np.mean(sepal_length)
median = np.median(sepal_length)
variance = np.var(sepal_length, ddof=1)
std_dev = np.std(sepal_length, ddof=1)
print("Mean:", mean)
print("Median:", median)
print("Variance:", variance)
print("Standard Deviation:", std_dev)
# Out:
# Mean: 5.843333333333334
# Median: 5.8
# Variance: 0.6856935123042507
# Standard Deviation: 0.828066127977863

# %%
from scipy.stats import kurtosis, skew

data = np.random.normal(0, 1, 1000)
kurt = kurtosis(data)
skewness = skew(data)
print("Kurtosis:", kurt)
print("Skewness:", skewness)
# Out:
# Kurtosis: 0.15040362220026626
# Skewness: 0.01699814460879659
